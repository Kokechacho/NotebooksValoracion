# %% [markdown]
# #### Copyright 2024 Álvaro Sánchez-Paniagua Ríos
#
# #### SPDX-License-Identifier: MIT
#
# # Estrategias con opciones
#
# ## 1. Introducción
#
# En los mercados financieros, los Futuros y las Opciones están ganando relevancia como productos potenciales para los inversionistas. Obtener más información sobre estos instrumentos financieros es crucial para comprender su funcionamiento y cómo aprovecharlos.
#
# En Futuros y Opciones Financieras, Jaime Díaz Tinoco y Fausto Hernández Trillo definen la Opción como un contrato que otorga al comprador el derecho, pero no la obligación, de comprar o vender un activo a un precio y fecha predeterminados. Hay dos tipos de opciones: **las de Compra** (Call), donde el comprador tiene **el derecho a comprar** el activo, y **las de Venta** (Put), donde el comprador tiene **el derecho a venderlo**.
#
# ## 2. Arbitraje
#
# El arbitraje con opciones financieras es **una estrategia de inversión** que aprovecha las disparidades de precios entre diferentes activos financieros para generar ganancias. Consiste en **adquirir un activo subvaluado y vender otro sobrevalorado** simultáneamente para beneficiarse de la diferencia de precios. En el caso de las opciones financieras, esto implica la compra y venta simultánea de opciones de compra o venta con diferentes precios de ejercicio o fechas de vencimiento.
#
# ## 3. Tipos de arbitraje y ejercicios
#
# ### 3.1. CALL CUBIERTO
#
# La estrategia de call cubierto consiste en** comprar acciones de un activo subyacente y vender simultáneamente una opción de compra sobre ese mismo activ**o. Se utiliza cuando se espera que el precio del activo subyacente aumente ligeramente o se mantenga estable. Si el precio del activo subyacente sube, el comprador de la opción de compra puede ejercerla, pero el vendedor ya tiene las acciones subyacentes para vender. Si el precio no cambia, el vendedor conserva la prima recibida por vender la opción
#
# #### EJERCICIO 1
#
# Queremos invertir en bolsa con esta estrategia en la URJC Corp, cuyo precio es de 50€ la acción, y decidimos comprar 100, por lo que nos costaría 5000€.
#
# Al mismo tiempo vendemos una opción de compra sobre URJC Corp con un precio de ejercicio de 55€ y a 3€ la prima. Recibimos entonces 300€ en total (3€x100 acciones)
#
# **Calcula que escenario es más rentable en base a las ganancias que te proporcione**
#
# 1. Escenario 1: URJC Corp sube en bolsa y supera los 55€ antes del vencimiento de la opción. (¿El comprador ejercerá su derecho?)
# 2. Escenario 2: URJC se desploma y no alcanza los 55€. (¿El comprador ejercerá su derecho?)
#
# <div style="background-color: #A9DFBF; padding: 10px;">
#     <details style="color: black;">
#         <summary>💡 Pista</summary>
#
#     >> Si el precio está por debajo de los 55€ no tiene sentido que el comprador ejerza su derecho de compra. (Estaría comprando más caro de lo que estaría en el mercado)
#
# </div>
#
# *--Ejecuta el código con Shift + Enter--*.

# %%
# ------------- AQUI VA TU CÓDIGO -----------------------------

# %% [markdown]
# <div style="background-color: #AED6F1; padding: 10px;">
#     <details style="color: black;">
#         <summary>Solución</summary>
#
#     >> Rentabilidad_escenario_1 = (5500+300)-5000 # = 800 | Vendes acciones y conservas la prima
#
#     >> Rentabilidad_escenario_2 = 300 # Conservas las acciones y la prima
#
#     >> Respuesta: ESCENARIO 1
#
#     >> Esta estrategia te protege parcialmente contra las pérdidas y obtienes beneficios si el precio sube
#
# </div>

# %% [markdown]
# ### 3.2. PUT PROTEGIDO
#
# La estrategia de put protegido implica **la compra de acciones de un activo subyacente y la compra simultánea de una opción de venta sobre ese mismo activo**. Se utiliza cuando se espera que el precio del activo subyacente disminuya ligeramente o se mantenga estable. Si el precio del activo subyacente cae, el comprador de la opción de venta puede ejercerla, pero el poseedor de las acciones subyacentes ya tiene la opción de venderlas al comprador de la opción de venta a un precio determinado. Si el precio del activo subyacente no cambia, el comprador de la opción de venta pierde la prima que pagó por la opción.
#
# #### EJERCICIO 2
#
# Somos el contrincante del inversor del ejercicio 1.
#
# Queremos invertir en bolsa con esta estrategia análoga también en la URJC Corp, cuyo precio es de 50€ la acción, y decidimos comprar 100, por lo que nos costaría 5000€.
#
# Al mismo tiempo compramos una opción de venta sobre URJC Corp con un precio de ejercicio de 45€ y a 2€ la prima. Pagamos entonces 200€ en total (2€x100 acciones)
#
# **Calcula que escenario es más rentable en base a las ganancias que te proporcione**
#
# 1. Escenario 1: URJC Corp sube en bolsa y supera los 45€ antes del vencimiento de la opción. (¿Ejerceremos nuestra opción de venta?)
# 2. Escenario 2: URJC se desploma y no alcanza los 45€. (¿Ejerceremos nuestra opción de venta?)
#
# <div style="background-color: #A9DFBF; padding: 10px;">
#     <details style="color: black;">
#         <summary>💡 Pista</summary>
#
#     >> Si el precio está por encima de los 45€ no tiene sentido que nos interese ejercer el derecho a venta (Estaríamos vendiendo a un precio por debajo de lo que se vende en el mercado)
#
# </div>
#
# *--Ejecuta el código con Shift + Enter--*

# %%
# ------------- AQUI VA TU CÓDIGO -----------------------------

# %% [markdown]
# <div style="background-color: #AED6F1; padding: 10px;">
#     <details style="color: black;">
#         <summary>Solución</summary>
#
#     >> Rentabilidad_escenario_1 = -200 # Conservas las acciones y pierdes la prima
#
#     >> Rentabilidad_escenario_2 = (4500 + 200) - 5000 # = -300 | Vendes acciones y conservas prima
#
#     >> Respuesta: ESCENARIO 1
#
# </div>

# %% [markdown]
# ### 3.3. STRADDLE
#
# Una estrategia de straddle implica **la compra simultánea de una opción de compra y una opción de venta** en el mismo activo subyacente, con el mismo precio de ejercicio y la misma fecha de vencimiento. Se utiliza cuando se espera una volatilidad significativa en el precio del activo subyacente, pero no se sabe en qué dirección se moverá el precio. Si el precio del activo subyacente aumenta por encima del precio de ejercicio de la opción de compra, el comprador de la opción de compra puede ejercerla y obtener ganancias. Si el precio del activo subyacente cae por debajo del precio de ejercicio de la opción de venta, el comprador de la opción de venta puede ejercerla y obtener ganancias. Si el precio del activo subyacente no cambia mucho, el comprador de ambas opciones pierde la prima que pagó por las opciones.
#
# #### EJERCICIO 3
#
# Siendo nosotros el inversor número 3 y viendo que los inversores anteriores no obtienen ganancias muy grandes dicidimos usar la estrategia con Stranddle.
#
# Queremos invertir en bolsa también en la URJC Corp, cuyo precio es de 50€ la acción, aunque como hay tantos inversores interesados últimamente en URJC Corp intuimos que dentro de poco ocurrirá algo que modifique sustancialmente el precio de la acción.
#
# Compramos simultáneamente entonces una opción de compra y otra de venta, ambas a un precio de ejercicio de 50€ y con una prima de 3€ por acción.
#
# **Calcula que escenario es más rentable en base a las ganancias que te proporcione**
#
# 1. Escenario 1: URJC Corp sube en bolsa y supera los 56€ antes del vencimiento de la opción, ya que la demanda de múltiples inversores hizo que URJC se revalorizara. (¿Ejerceremos nuestras opciones?)
# 2. Escenario 2: URJC se desploma y no alcanza los 44€ debido a que tantas expectativas sobre URJC Corp lo convirtió en una burbuja. (¿Ejerceremos nuestras opciones?)
# 3. Escenario 3: URJC Corp se mantiene estable y sigue rondando los 50€. (¿Ejerceremos nuestras opciones?)
#
# <div style="background-color: #A9DFBF; padding: 10px;">
#     <details style="color: black;">
#         <summary>💡 Pista</summary>
#
#     >> Si sube mucho el precio quizás me interese ejercer el derecho de la opción de compra para obtener ganancias, mientras que no debería ejercer la venta de mis acciones ya que el precio de mercado está mucho más alto.
#
# </div>
#
# *--Ejecuta el código con Shift + Enter--*

# %%
# ------------- NO MODIFICAR ESTE CÓDIGO -------------------------
import numpy as np
import matplotlib.pyplot as plt

K_call = 50  # Precio de ejercicio de la opción de compra
K_put = 50   # Precio de ejercicio de la opción de venta
premium_call = 3  # Prima de la opción de compra
premium_put = 3   # Prima de la opción de venta

# Función para calcular el payoff de una opción de compra
def payoff_call(S, K, premium):
    return np.maximum(S - K, 0) - premium

# Función para calcular el payoff de una opción de venta
def payoff_put(S, K, premium):
    return np.maximum(K - S, 0) - premium

# Función para calcular el payoff total del straddle
def payoff_straddle(S, K_call, K_put, premium_call, premium_put):
    return payoff_call(S, K_call, premium_call) + payoff_put(S, K_put, premium_put)

# Precios del activo subyacente
S_range = np.linspace(40, 60, 100)

# Calcular el payoff del straddle
payoff = payoff_straddle(S_range, K_call, K_put, premium_call, premium_put)
plt.figure(figsize=(10, 6))

# %%
# ------------- AQUI VA TU CÓDIGO -----------------------------
# GRAFICA QUE PASARÍA EN EL ESCENARIO 1 -> PRECIO EN 60 
# GRAFICA QUE PASARÍA EN EL ESCENARIO 1 -> PRECIO EN 42
# GRAFICA QUE PASARÍA EN EL ESCENARIO 1 -> PRECIO EN 50.5
# PARA GRAFICAR LINEAS VERTICALES USAMOS:
# plt.axvline(x ...)
# EJEMPLO PARA GRAFICAR UNA LINEA EN X = 45 -----> plt.axvline(45)


# ------------- NO MODIFICAR ESTE CÓDIGO -------------------------
# Graficar el payoff del straddle

plt.plot(S_range, payoff, label='Payoff del Straddle', color='blue', linestyle='-')
plt.axhline(0, color='black', linestyle='--')
plt.axvline(K_call + premium_call, color='red', linestyle='--', label='Precio de ejercicio de la opción de compra + prima')
plt.axvline(K_put - premium_put, color='green', linestyle='--', label='Precio de ejercicio de la opción de venta - prima')
plt.xlabel('Precio del activo subyacente')
plt.ylabel('Payoff')
plt.title('Payoff de una estrategia de straddle')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <div style="background-color: #AED6F1; padding: 10px;">
#     <details style="color: black;">
#         <summary>Solución</summary>
#
#     >> plt.axvline(60)
#
#     >> plt.axvline(42)
#
#     >> plt.axvline(50.5)
#
#     >> Escenario 1: Obtenemos ganancias una vez ejercemos nuestra opción de compra cuando sube por encima de los 56€.
#
#     >> Escenario 2: Obtenemos ganancias una vez ejercemos nuestra opción de venta cuando baja por debajo de los 44€
#
#     >> Escenario 3: Pérdidas, al no poder ejercer ninguna opción perderemos ambas primas.
#
# </div>

# %% [markdown]
# ### 3.4. STRAGDLE
#
# Una estrategia de strangle es similar a la estrategia de straddle, pero **implica la compra simultánea de una opción de compra y una opción de venta en el mismo activo subyacente, con diferentes precios de ejercicio** y la misma fecha de vencimiento. Se utiliza cuando se espera una volatilidad significativa en el precio del activo subyacente, pero se espera que el precio se mueva en una dirección u otra. Si el precio del activo subyacente aumenta por encima del precio de ejercicio de la opción de compra, el comprador de la opción de compra puede ejercerla y obtener ganancias. Si el precio del activo subyacente cae por debajo del precio de ejercicio de la opción de venta, el comprador de la opción de venta puede ejercerla y obtener ganancias. Si el precio del activo subyacente no cambia mucho, el comprador de ambas opciones incurrirá en pérdidas debido al costo de las primas pagadas.
#
# #### EJERCICIO 4
#
# En conclusión, siendo el último inversor, vamos a plagiar al inversor número 3 y hacer esa misma estrategia pero cambiando los precios de las opciones.
#
# Queremos invertir en bolsa también en la URJC Corp, cuyo precio es de 50€ la acción.
#
# Compramos simultáneamente entonces una opción de compra y otra de venta a distintos precios:
#
# a) Opción de compra: precio de 55€ y prima de 3€
# b) Opción de venta: precio de 45€ y prima de 3€
#
# **Modifica los parámetros para ver como cambia el gráfico**

# %%
# ------------- NO MODIFICAR ESTE CÓDIGO -------------------------
import numpy as np
import matplotlib.pyplot as plt

# -------------- Modifica estos parámetros --------------
K_call = 55  # Precio de ejercicio de la opción de compra
K_put = 45   # Precio de ejercicio de la opción de venta
premium_call = 3  # Prima de la opción de compra
premium_put = 3   # Prima de la opción de venta

# Función para calcular el payoff de una opción de compra
def payoff_call(S, K, premium):
    return np.maximum(S - K, 0) - premium

# Función para calcular el payoff de una opción de venta
def payoff_put(S, K, premium):
    return np.maximum(K - S, 0) - premium

# Función para calcular el payoff total del strangle
def payoff_strangle(S, K_call, K_put, premium_call, premium_put):
    return payoff_call(S, K_call, premium_call) + payoff_put(S, K_put, premium_put)

# Precios del activo subyacente
S_range = np.linspace(40, 60, 100)

# Calcular el payoff del strangle
payoff = payoff_strangle(S_range, K_call, K_put, premium_call, premium_put)

# Graficar el payoff del strangle
plt.figure(figsize=(10, 6))
plt.plot(S_range, payoff, label='Payoff del Strangle', color='blue', linestyle='-')
plt.axhline(0, color='black', linestyle='--')
plt.axvline(K_call + premium_call, color='red', linestyle='--', label='Precio de ejercicio de la opción de compra + prima')
plt.axvline(K_put - premium_put, color='green', linestyle='--', label='Precio de ejercicio de la opción de venta - prima')
plt.xlabel('Precio del activo subyacente')
plt.ylabel('Payoff')
plt.title('Payoff de una estrategia de strangle')
plt.legend()
plt.grid(True)
plt.show()
